# %% [markdown]
# ### Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_source = pd.read_csv("NFT_Top_Collections.csv")

# %%
df_source_five = df_source.head(5)
df_source_five
# Out:
#    Index                               Name    Volume    Volume_USD  \
# 0      0                      basis.markets  27256.63  4.001818e+06
# 1      1               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2      2                           Flippies   6732.19  9.884201e+05
# 3      3  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4      4                      Stylish Studs   3191.15  4.685246e+05
#
#     Market_Cap  Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  \
# 0   708.145455    103969.91560    366        39.50        5799.3900
# 1   106.656000     15659.23392   2075         0.67          98.3694
# 2  1663.863158    244288.38880   1504         0.80         117.4560
# 3    90.275000     13254.17550    395         3.79         556.4478
# 4   165.000000     24225.30000    729         4.30         631.3260
#
#    Average_Price  Average_Price_USD  Owners  Assets  Owner_Asset_Ratio  \
# 0      74.471667       10933.930100      12      16              75.00
# ...

# %%
df_source_five_T = df_source_five.T
df_source_five_T
# Out:
#                                                                    0  \
# Index                                                              0
# Name                                                   basis.markets
# Volume                                                      27256.63
# Volume_USD                                               4001818.417
# Market_Cap                                                708.145455
# Market_Cap_USD                                           103969.9156
# Sales                                                            366
# Floor_Price                                                     39.5
# Floor_Price_USD                                              5799.39
# Average_Price                                              74.471667
# Average_Price_USD                                         10933.9301
# Owners                                                            12
# Assets                                                            16
# ...

# %%
df_source_five_T.iloc[16].to_list()
# Out:
# ['https://content.solsea.io/files/thumbnail/1636669983973-23915727-basis-markets-banner-design-01.jpg',
#  'https://content.solsea.io/files/thumbnail/1633080381187-181516172-Solsea Profile Image@2x.png',
#  'https://content.solsea.io/files/thumbnail/1632312299559-878440662-FlippiesOriginal02.png',
#  'https://content.solsea.io/files/thumbnail/1632759644698-41570094-kkjewfw - Meerkat Millionaire.png',
#  'https://content.solsea.io/files/thumbnail/1632756712180-920281342-StylishStuds_500x500 - Ian Cummings.png']
